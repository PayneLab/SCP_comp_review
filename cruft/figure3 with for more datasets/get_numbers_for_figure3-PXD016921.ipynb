# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/peptide_files/AllQuantifiedPeptides_PXD016921.tsv', sep='\t')

# %%
df.head()
# Out:
#                         Sequence                  Base Sequence  \
# 0  AAAAAAAAAPAAAATAPTTAATTAATAAQ  AAAAAAAAAPAAAATAPTTAATTAATAAQ
# 1                   AAAAAAAAAVSR                   AAAAAAAAAVSR
# 2                    AAAAAAALQAK                    AAAAAAALQAK
# 3                     AAAAADLANR                     AAAAADLANR
# 4              AAAAAWEEPSSGNGTAR              AAAAAWEEPSSGNGTAR
#
#   Protein Groups Gene Names      Organism  Intensity_100 HeLa cells-calib  \
# 0         P37108      SRP14  Homo sapiens                    2.139006e+05
# 1         Q96JP5      ZFP91  Homo sapiens                    3.956375e+04
# 2         P36578       RPL4  Homo sapiens                    2.806793e+06
# 3         O76031       CLPX  Homo sapiens                    5.665067e+04
# 4         Q9P258       RCC2  Homo sapiens                    1.485849e+05
#
#    Intensity_Single cell 1-calib  Intensity_Single cell 2-calib  \
# 0                   0.000000e+00                   0.000000e+00
# 1                   0.000000e+00                   0.000000e+00
# 2                   1.439909e+06                   1.426858e+06
# 3                   0.000000e+00                   0.000000e+00
# 4                   0.000000e+00                   0.000000e+00
#
#    Intensity_Single cell 3-calib  Intensity_Single cell 4-calib  \
# 0                   0.000000e+00                   7.797498e+04
# 1                   0.000000e+00                   0.000000e+00
# 2                   1.655869e+06                   1.952211e+06
# 3                   0.000000e+00                   8.559925e+04
# 4                   0.000000e+00                   0.000000e+00
#
#    Intensity_20 HeLa cells-calib Detection Type_100 HeLa cells-calib  \
# 0                   1.320578e+05                                MSMS
# 1                   3.322283e+04                                MSMS
# 2                   2.803523e+06                                MSMS
# 3                   4.435015e+04                                MSMS
# 4                   4.161260e+04                                MSMS
#
#   Detection Type_Single cell 1-calib Detection Type_Single cell 2-calib  \
# 0                        NotDetected                        NotDetected
# 1                        NotDetected                        NotDetected
# 2                               MSMS                               MSMS
# 3                        NotDetected                        NotDetected
# 4                        NotDetected                        NotDetected
#
#   Detection Type_Single cell 3-calib Detection Type_Single cell 4-calib  \
# 0                        NotDetected                                MBR
# 1                        NotDetected                        NotDetected
# 2                               MSMS                               MSMS
# 3                        NotDetected                                MBR
# 4                        NotDetected                        NotDetected
#
#   Detection Type_20 HeLa cells-calib  Unnamed: 17
# 0                               MSMS          NaN
# 1                                MBR          NaN
# 2                               MSMS          NaN
# 3                                MBR          NaN
# 4                                MBR          NaN

# %%
# we need to get the PGM1 protein and see if it's kind of looking the same.

# %%
df_peptide_notshared = df[~df['Protein Groups'].str.contains(';')]
df_peptide_notshared 

df_peptide_shared = df[df['Protein Groups'].str.contains(';')]
df_peptide_shared

df_peptide_shared['gene_split'] = df_peptide_shared['Gene Names'].str.split(';')
# df_peptide_shared[['Gene Names', 'gene_split']]

#expand the rows. the concat onto other df
df2_pep_shared = df_peptide_shared.explode('gene_split').reset_index(drop=True)
df2_pep_shared['Gene Names'] = df2_pep_shared['Gene Names'].str.split(';').str[0]
df2_pep_shared = df2_pep_shared[df2_pep_shared['gene_split'] != ""] #without this line protein that have the format AAX; are added twice

df_combined = pd.concat([df_peptide_notshared, df2_pep_shared])
df_combined
# Out:
# /var/folders/zk/jc657sbs27l7_q82ygdlvxxc0000gp/T/ipykernel_39225/226859099.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_peptide_shared['gene_split'] = df_peptide_shared['Gene Names'].str.split(';')
#                                              Sequence  \
# 0                       AAAAAAAAAPAAAATAPTTAATTAATAAQ
# 1                                        AAAAAAAAAVSR
# 2                                         AAAAAAALQAK
# 3                                          AAAAADLANR
# 4                                   AAAAAWEEPSSGNGTAR
# ...                                               ...
# 5603  YVLHC[Common Fixed:Carbamidomethyl on C]QGTEEEK
# 5605                                      YVRPFLNSISK
# 5607                                        YYPTEDVPR
# 5609                                       YYPTEDVPRK
# 5611                                     YYVTIIDAPGHR
#
#                       Base Sequence           Protein Groups       Gene Names  \
# 0     AAAAAAAAAPAAAATAPTTAATTAATAAQ                   P37108            SRP14
# 1                      AAAAAAAAAVSR                   Q96JP5            ZFP91
# 2                       AAAAAAALQAK                   P36578             RPL4
# 3                        AAAAADLANR                   O76031             CLPX
# 4                 AAAAAWEEPSSGNGTAR                   Q9P258             RCC2
# ...                             ...                      ...              ...
# 5603                   YVLHCQGTEEEK         P62495;UNDEFINED             ETF1
# 5605                    YVRPFLNSISK         O00231;UNDEFINED           PSMD11
# 5607                      YYPTEDVPR         Q02878;UNDEFINED             RPL6
# 5609                     YYPTEDVPRK         Q02878;UNDEFINED             RPL6
# 5611                   YYVTIIDAPGHR  P68104|Q5VTE0;UNDEFINED  EEF1A1|EEF1A1P5
#
#            Organism  Intensity_100 HeLa cells-calib  \
# 0      Homo sapiens                    2.139006e+05
# 1      Homo sapiens                    3.956375e+04
# 2      Homo sapiens                    2.806793e+06
# 3      Homo sapiens                    5.665067e+04
# 4      Homo sapiens                    1.485849e+05
# ...             ...                             ...
# 5603  Homo sapiens;                    3.553401e+05
# 5605  Homo sapiens;                    1.798815e+05
# 5607  Homo sapiens;                    7.464108e+05
# 5609  Homo sapiens;                    7.534751e+05
# 5611  Homo sapiens;                    8.722422e+06
#
#       Intensity_Single cell 1-calib  Intensity_Single cell 2-calib  \
# 0                      0.000000e+00                   0.000000e+00
# 1                      0.000000e+00                   0.000000e+00
# 2                      1.439909e+06                   1.426858e+06
# 3                      0.000000e+00                   0.000000e+00
# 4                      0.000000e+00                   0.000000e+00
# ...                             ...                            ...
# 5603                   0.000000e+00                   1.630871e+05
# 5605                   0.000000e+00                   0.000000e+00
# 5607                   8.085435e+05                   6.553502e+05
# 5609                   6.089860e+05                   4.520617e+05
# 5611                   4.691009e+06                   5.351958e+06
#
#       Intensity_Single cell 3-calib  Intensity_Single cell 4-calib  \
# 0                      0.000000e+00                   7.797498e+04
# 1                      0.000000e+00                   0.000000e+00
# 2                      1.655869e+06                   1.952211e+06
# 3                      0.000000e+00                   8.559925e+04
# 4                      0.000000e+00                   0.000000e+00
# ...                             ...                            ...
# 5603                   3.105197e+05                   0.000000e+00
# 5605                   0.000000e+00                   3.728543e+04
# 5607                   9.907151e+05                   6.004674e+05
# 5609                   5.682037e+05                   4.538533e+05
# 5611                   1.127036e+07                   5.969055e+06
#
#       Intensity_20 HeLa cells-calib Detection Type_100 HeLa cells-calib  \
# 0                      1.320578e+05                                MSMS
# 1                      3.322283e+04                                MSMS
# 2                      2.803523e+06                                MSMS
# 3                      4.435015e+04                                MSMS
# 4                      4.161260e+04                                MSMS
# ...                             ...                                 ...
# 5603                   6.367727e+04                                MSMS
# 5605                   9.224258e+04                                MSMS
# 5607                   6.605884e+05                                MSMS
# 5609                   3.893537e+05                                MSMS
# 5611                   4.645863e+06                                MSMS
#
#      Detection Type_Single cell 1-calib Detection Type_Single cell 2-calib  \
# 0                           NotDetected                        NotDetected
# 1                           NotDetected                        NotDetected
# 2                                  MSMS                               MSMS
# 3                           NotDetected                        NotDetected
# 4                           NotDetected                        NotDetected
# ...                                 ...                                ...
# 5603                        NotDetected                                MBR
# 5605                        NotDetected                        NotDetected
# 5607                               MSMS                               MSMS
# 5609                                MBR                                MBR
# 5611                               MSMS                               MSMS
#
#      Detection Type_Single cell 3-calib Detection Type_Single cell 4-calib  \
# 0                           NotDetected                                MBR
# 1                           NotDetected                        NotDetected
# 2                                  MSMS                               MSMS
# 3                           NotDetected                                MBR
# 4                           NotDetected                        NotDetected
# ...                                 ...                                ...
# 5603                                MBR                        NotDetected
# 5605                        NotDetected                                MBR
# 5607                               MSMS                               MSMS
# 5609                               MSMS                                MBR
# 5611                               MSMS                               MSMS
#
#      Detection Type_20 HeLa cells-calib  Unnamed: 17       gene_split
# 0                                  MSMS          NaN              NaN
# 1                                   MBR          NaN              NaN
# 2                                  MSMS          NaN              NaN
# 3                                   MBR          NaN              NaN
# 4                                   MBR          NaN              NaN
# ...                                 ...          ...              ...
# 5603                               MSMS          NaN             ETF1
# 5605                               MSMS          NaN           PSMD11
# 5607                               MSMS          NaN             RPL6
# 5609                               MSMS          NaN             RPL6
# 5611                               MSMS          NaN  EEF1A1|EEF1A1P5
#
# [16863 rows x 19 columns]

# %%
df_combined.columns
# Out:
# Index(['Sequence', 'Base Sequence', 'Protein Groups', 'Gene Names', 'Organism',
#        'Intensity_100 HeLa cells-calib', 'Intensity_Single cell 1-calib',
#        'Intensity_Single cell 2-calib', 'Intensity_Single cell 3-calib',
#        'Intensity_Single cell 4-calib', 'Intensity_20 HeLa cells-calib',
#        'Detection Type_100 HeLa cells-calib',
#        'Detection Type_Single cell 1-calib',
#        'Detection Type_Single cell 2-calib',
#        'Detection Type_Single cell 3-calib',
#        'Detection Type_Single cell 4-calib',
#        'Detection Type_20 HeLa cells-calib', 'Unnamed: 17', 'gene_split'],
#       dtype='object')

# %%
#how many proteins are there total?
df_combined = df_combined[['Gene Names','Sequence',
    'Intensity_Single cell 1-calib',
       'Intensity_Single cell 2-calib', 'Intensity_Single cell 3-calib',
       'Intensity_Single cell 4-calib'
   ]]

# %%
#Calculates the total spectral count for each row. Will help to find examples
def calc_totals(row):
    total = 0
    if row[2] != 0:
        total += 1
    if row[3] != 0:
        total += 1
    if row[4] != 0:
        total += 1
    if row[5] != 0:
        total += 1
    return total


df_with_totals = df_combined.copy()
df_with_totals['Total_Count'] = df_with_totals.apply(calc_totals, axis = 1)
df_with_totals = df_with_totals[~df_with_totals['Gene Names'].isnull()]

# %%
df_with_totals
# Out:
#            Gene Names                                         Sequence  \
# 0               SRP14                    AAAAAAAAAPAAAATAPTTAATTAATAAQ
# 1               ZFP91                                     AAAAAAAAAVSR
# 2                RPL4                                      AAAAAAALQAK
# 3                CLPX                                       AAAAADLANR
# 4                RCC2                                AAAAAWEEPSSGNGTAR
# ...               ...                                              ...
# 5603             ETF1  YVLHC[Common Fixed:Carbamidomethyl on C]QGTEEEK
# 5605           PSMD11                                      YVRPFLNSISK
# 5607             RPL6                                        YYPTEDVPR
# 5609             RPL6                                       YYPTEDVPRK
# 5611  EEF1A1|EEF1A1P5                                     YYVTIIDAPGHR
#
#       Intensity_Single cell 1-calib  Intensity_Single cell 2-calib  \
# 0                      0.000000e+00                   0.000000e+00
# 1                      0.000000e+00                   0.000000e+00
# 2                      1.439909e+06                   1.426858e+06
# 3                      0.000000e+00                   0.000000e+00
# 4                      0.000000e+00                   0.000000e+00
# ...                             ...                            ...
# 5603                   0.000000e+00                   1.630871e+05
# 5605                   0.000000e+00                   0.000000e+00
# 5607                   8.085435e+05                   6.553502e+05
# 5609                   6.089860e+05                   4.520617e+05
# 5611                   4.691009e+06                   5.351958e+06
#
#       Intensity_Single cell 3-calib  Intensity_Single cell 4-calib  \
# 0                      0.000000e+00                   7.797498e+04
# 1                      0.000000e+00                   0.000000e+00
# 2                      1.655869e+06                   1.952211e+06
# 3                      0.000000e+00                   8.559925e+04
# 4                      0.000000e+00                   0.000000e+00
# ...                             ...                            ...
# 5603                   3.105197e+05                   0.000000e+00
# 5605                   0.000000e+00                   3.728543e+04
# 5607                   9.907151e+05                   6.004674e+05
# 5609                   5.682037e+05                   4.538533e+05
# 5611                   1.127036e+07                   5.969055e+06
#
#       Total_Count
# 0               1
# 1               0
# 2               4
# 3               1
# 4               0
# ...           ...
# 5603            2
# 5605            1
# 5607            4
# 5609            4
# 5611            4
#
# [16111 rows x 7 columns]

# %%
df_gene_ind = df_with_totals.set_index(['Gene Names', 'Sequence']) #create a multiindex dataframe
df_gene_ind = df_gene_ind[df_gene_ind['Total_Count']>0]#drop rows that don't have any intensities in any col. Who knows why that's a thing
df_gene_ind.sort_index()
# Out:
#                                                               Intensity_Single cell 1-calib  \
# Gene Names Sequence
# A2M        QTVSWAVTPK                                                              0.000000
# AAMP       LSDGELLFEC[Common Fixed:Carbamidomethyl on C]AGHK                       0.000000
# AARS1      AVYTQDC[Common Fixed:Carbamidomethyl on C]PLAAAK                        0.000000
#            EADGILKPLPK                                                             0.000000
#            IQSLGDSK                                                                0.000000
# ...                                                                                     ...
# ZYX        QNVAVNELC[Common Fixed:Carbamidomethyl on C]GR                     139079.789651
#            SPGAPGPLTLK                                                        137336.505427
#            SSTKPAAGGTAPLPPWK                                                       0.000000
#            VNPFRPGDSEPPPAPGAQR                                                     0.000000
#            VSSGYVPPPVATPFSSK                                                       0.000000
#
#                                                               Intensity_Single cell 2-calib  \
# Gene Names Sequence
# A2M        QTVSWAVTPK                                                              0.000000
# AAMP       LSDGELLFEC[Common Fixed:Carbamidomethyl on C]AGHK                   58020.996678
# AARS1      AVYTQDC[Common Fixed:Carbamidomethyl on C]PLAAAK                        0.000000
#            EADGILKPLPK                                                             0.000000
#            IQSLGDSK                                                                0.000000
# ...                                                                                     ...
# ZYX        QNVAVNELC[Common Fixed:Carbamidomethyl on C]GR                     397699.506332
#            SPGAPGPLTLK                                                        592739.895745
#            SSTKPAAGGTAPLPPWK                                                   68156.019184
#            VNPFRPGDSEPPPAPGAQR                                                313787.237620
#            VSSGYVPPPVATPFSSK                                                       0.000000
#
#                                                               Intensity_Single cell 3-calib  \
# Gene Names Sequence
# A2M        QTVSWAVTPK                                                          1.072371e+05
# AAMP       LSDGELLFEC[Common Fixed:Carbamidomethyl on C]AGHK                   0.000000e+00
# AARS1      AVYTQDC[Common Fixed:Carbamidomethyl on C]PLAAAK                    0.000000e+00
#            EADGILKPLPK                                                         0.000000e+00
#            IQSLGDSK                                                            0.000000e+00
# ...                                                                                     ...
# ZYX        QNVAVNELC[Common Fixed:Carbamidomethyl on C]GR                      1.097924e+06
#            SPGAPGPLTLK                                                         1.111464e+06
#            SSTKPAAGGTAPLPPWK                                                   0.000000e+00
#            VNPFRPGDSEPPPAPGAQR                                                 2.941845e+05
#            VSSGYVPPPVATPFSSK                                                   0.000000e+00
#
#                                                               Intensity_Single cell 4-calib  \
# Gene Names Sequence
# A2M        QTVSWAVTPK                                                          6.628289e+04
# AAMP       LSDGELLFEC[Common Fixed:Carbamidomethyl on C]AGHK                   1.696516e+04
# AARS1      AVYTQDC[Common Fixed:Carbamidomethyl on C]PLAAAK                    1.182799e+05
#            EADGILKPLPK                                                         6.491784e+04
#            IQSLGDSK                                                            6.889817e+04
# ...                                                                                     ...
# ZYX        QNVAVNELC[Common Fixed:Carbamidomethyl on C]GR                      7.452230e+05
#            SPGAPGPLTLK                                                         1.173231e+06
#            SSTKPAAGGTAPLPPWK                                                   3.672728e+04
#            VNPFRPGDSEPPPAPGAQR                                                 4.838050e+05
#            VSSGYVPPPVATPFSSK                                                   1.026720e+05
#
#                                                               Total_Count
# Gene Names Sequence
# A2M        QTVSWAVTPK                                                   2
# AAMP       LSDGELLFEC[Common Fixed:Carbamidomethyl on C]AGHK            2
# AARS1      AVYTQDC[Common Fixed:Carbamidomethyl on C]PLAAAK             1
#            EADGILKPLPK                                                  1
#            IQSLGDSK                                                     1
# ...                                                                   ...
# ZYX        QNVAVNELC[Common Fixed:Carbamidomethyl on C]GR               4
#            SPGAPGPLTLK                                                  4
#            SSTKPAAGGTAPLPPWK                                            2
#            VNPFRPGDSEPPPAPGAQR                                          3
#            VSSGYVPPPVATPFSSK                                            1
#
# [13073 rows x 5 columns]

# %%
len(list(df_gene_ind.index.get_level_values('Gene Names').unique()))
# Out:
# 2118

# %%
len(list(df_gene_ind.index.get_level_values('Sequence')))
# Out:
# 13073

# %%
no_consistent= []
one_consistent = []
two_consistent = []
three_consistent = []
fourplus_consistent = []

num_proteins = 0

for gene, gene_df in df_gene_ind.groupby(level=0):
    num_proteins+=1
    #loop through each gene and count the number of consistent peptides
    if len(gene_df[gene_df['Total_Count'] == 4]) == 0:
        no_consistent.append(gene)
    elif len(gene_df[gene_df['Total_Count'] == 4]) == 1:
        one_consistent.append(gene)
    elif len(gene_df[gene_df['Total_Count'] == 4]) == 2:
#         import pdb; pdb.set_trace()
        two_consistent.append(gene)
    elif len(gene_df[gene_df['Total_Count'] == 4]) == 3:
        three_consistent.append(gene)
    elif len(gene_df[gene_df['Total_Count'] == 4]) >= 4:
        fourplus_consistent.append(gene)
        
    else:
        print('something is wrong')

# %%
len(fourplus_consistent)
# Out:
# 385

# %%
len(three_consistent)
# Out:
# 110

# %%
num_proteins
# Out:
# 2118

# %%
'''
returns a dictionary where the key is the number of peptides, 
and the value is the number of proteins
Example: 5:4 would mean that 4 proteins consist of 5 peptides
'''
def get_num_pep_dict(df_with_totals, pep_consistency_list):
    subdf = df_with_totals[df_with_totals['Gene Names'].isin(pep_consistency_list)]
    subdf = subdf.set_index(['Gene Names', 'Sequence']) #create a multiindex dataframe
    subdf = subdf[subdf['Total_Count']>0]#drop rows that don't have any intensities in any col. Who knows why that's a thing
    subdf = subdf.sort_index()
    
    
    num_pep_consis = {}
    for gene, gene_df in subdf.groupby(level=0):
        num_peptides = len(gene_df)
        if num_peptides not in num_pep_consis.keys():    
            num_pep_consis[num_peptides] = 1
        else:
            num_pep_consis[num_peptides] += 1

    return num_pep_consis

# %%
no_consis_d = get_num_pep_dict(df_with_totals, no_consistent)
one_consis_d = get_num_pep_dict(df_with_totals, one_consistent)
two_consis_d = get_num_pep_dict(df_with_totals, two_consistent)
three_consis_d = get_num_pep_dict(df_with_totals, three_consistent)
fourplus_consis_d = get_num_pep_dict(df_with_totals, fourplus_consistent)

# %%
no_consis_d
# Out:
# {1: 536,
#  7: 10,
#  4: 55,
#  14: 1,
#  5: 35,
#  6: 37,
#  3: 118,
#  2: 203,
#  10: 10,
#  9: 8,
#  8: 14,
#  11: 2,
#  32: 1,
#  13: 1,
#  15: 2}

# %% [markdown]
# ## make figure

# %%
num_pep_0consis_series = pd.Series(no_consis_d)
num_pep_1consis_series = pd.Series(one_consis_d)
num_pep_2consis_series = pd.Series(two_consis_d)
num_pep_3consis_series = pd.Series(three_consis_d)
num_pep_4plusconsis_series = pd.Series(fourplus_consis_d)

# %%
plotdf = pd.concat([num_pep_0consis_series,
           num_pep_1consis_series,
          num_pep_2consis_series,
          num_pep_3consis_series,
          num_pep_4plusconsis_series],axis=1)


plotdf.rename({0:'0',
              1:'1',
              2:'2',
              3:'3',
              4:'4'}, axis=1, inplace=True)

plotdf = plotdf.sort_index()

# %%
plotdf.head() #index is the number of peptides in a protein. Values are the number of proteins
# Out:
#        0     1     2     3    4
# 1  536.0  77.0   NaN   NaN  NaN
# 2  203.0  89.0  21.0   NaN  NaN
# 3  118.0  62.0  37.0   5.0  NaN
# 4   55.0  46.0  37.0  14.0  6.0
# 5   35.0  44.0  31.0  10.0  9.0

# %%
plotdf = plotdf.reset_index()

melted = pd.melt(plotdf, id_vars='index', value_vars=plotdf.columns.tolist())
melted.rename({'variable':'category', 'index':'total_peptides', 'value':'num_proteins'}, axis=1, inplace=True)
melted = melted[melted['num_proteins'].notnull()]
melted.head()

# make a boxplot
#each row is a protein
#y axis is the number of inconsistent
#x axis is the category

plot4 = melted.copy()
plot4



def get_inconsistent_count(row):
    num_consistent = int(row['category'].split(' ')[0])        
    num_total = row['total_peptides']
    if num_consistent == num_total:
        return 0
    else:
        num_inconsistent  = num_total - num_consistent
        return num_inconsistent
    
plot4 = melted.copy()
plot4['inconsistent_count'] = plot4.apply(get_inconsistent_count, axis=1)
plot4 = plot4.sort_values('category')
plot4.replace('4 consistent peptide', '4+ consistent peptide', inplace=True)
plot4.replace('4', '4+', inplace=True)


plot4.drop(columns='total_peptides', inplace=True)

plot4 = plot4.groupby(['category', 'inconsistent_count'])['num_proteins'].sum().unstack().fillna(0)

#format to deal with 4+
above4 = list(plot4.columns)
above4 = [x for x in above4 if x >= 4]
plot4['4+'] = plot4[above4].sum(axis=1)
plot4.drop(columns=above4, axis=1,inplace=True)

plot4 = plot4.rename({0:'0 inconsistent peptides',
             1:'1 inconsistent peptides',
             2:'2 inconsistent peptides',
             3:'3 inconsistent peptides',
             '4+':'4+ inconsistent peptides'}, axis=1)
plot4


from matplotlib import pyplot as plt

# Very simple one-liner using our agg_tips DataFrame.
ax = plot4.plot(kind='bar', stacked=True)

plt.xticks(rotation=0, ha='center')

ax.legend(bbox_to_anchor=(1., 1.03))

plt.xlabel('# of consistent peptides per protein', fontsize=18)
plt.ylabel('# of proteins', fontsize=18)
plt.savefig('stacked_bar_chart.png', dpi=600, bbox_inches = "tight")

plt.show()
# Out:
#      total_peptides category  num_proteins
# 0                 1        0         536.0
# 1                 2        0         203.0
# 2                 3        0         118.0
# 3                 4        0          55.0
# 4                 5        0          35.0
# ..              ...      ...           ...
# 280             127        4           1.0
# 281             139        4           1.0
# 282             149        4           1.0
# 283             156        4           1.0
# 284             209        4           1.0
#
# [117 rows x 3 columns]

# %%
plotdf.sum()
# Out:
# index    2443.0
# 0        1033.0
# 1         395.0
# 2         195.0
# 3         110.0
# 4         385.0
# dtype: float64

# %%
num_prot = len(list(df_gene_ind.index.get_level_values('Gene Names').unique()))

# %%
num_prot

# %%
print('0 consistent: ' + str(round(1022/num_prot*100, 2)))
print('1 consistent: ' + str(round(395/num_prot*100, 2)))
print('2 consistent: ' + str(round(195/num_prot*100,2)))
print('3 consistent: ' + str(round(110/num_prot*100,2)))
print('4+ consistent: ' + str(round(385/num_prot*100,2)))
