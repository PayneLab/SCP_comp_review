# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/peptide_files/AllQuantifiedPeptides_MSV000085937_NonDepleted_Lung_SingleCellProteomics.tsv', sep='\t')

# %%
df.head()
# Out:
#               Sequence        Base Sequence Protein Groups Gene Names  \
# 0          AAAAAAALQAK          AAAAAAALQAK         P36578       RPL4
# 1        AADAEAEVASLNR        AADAEAEVASLNR         P06753       TPM3
# 2            AAEDYGVIK            AAEDYGVIK      UNDEFINED        NaN
# 3  AAFDDAIAELDTLSEESYK  AAFDDAIAELDTLSEESYK         P62258      YWHAE
# 4            AAFGGSGGR            AAFGGSGGR      UNDEFINED        NaN
#
#        Organism  \
# 0  Homo sapiens
# 1  Homo sapiens
# 2           NaN
# 3  Homo sapiens
# 4           NaN
#
#    Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A1-calib  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.000000
# 3                                       16617.815755
# 4                                           0.000000
#
#    Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A2-calib  \
# 0                                         847.497855
# 1                                           0.000000
# 2                                       71568.381919
# 3                                        3419.939858
# 4                                           0.000000
#
#    Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A3-calib  \
# 0                                         757.421795
# 1                                           0.000000
# 2                                           0.000000
# 3                                        5049.622344
# 4                                       24510.043524
#
#    Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A4-calib  \
# 0                                         894.366601
# 1                                        3633.850551
# 2                                           0.000000
# 3                                        7665.270626
# 4                                         508.788045
#
#    Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A5-calib  ...  \
# 0                                         972.246076              ...
# 1                                           0.000000              ...
# 2                                           0.000000              ...
# 3                                        3659.233262              ...
# 4                                           0.000000              ...
#
#    Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_B02-calib  \
# 0                                        NotDetected
# 1                                        NotDetected
# 2                                        NotDetected
# 3                                                MBR
# 4                                        NotDetected
#
#    Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A10-calib  \
# 0                                                MBR
# 1                                                MBR
# 2                                        NotDetected
# 3                                                MBR
# 4                                        NotDetected
#
#    Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A11-calib  \
# 0                                        NotDetected
# 1                                        NotDetected
# 2                                        NotDetected
# 3                                                MBR
# 4                                        NotDetected
#
#    Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C3-calib  \
# 0                                        NotDetected
# 1                                        NotDetected
# 2                                        NotDetected
# 3                                                MBR
# 4                                        NotDetected
#
#    Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C4-calib  \
# 0                                        NotDetected
# 1                                        NotDetected
# 2                                        NotDetected
# 3                                        NotDetected
# 4                                        NotDetected
#
#    Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C5-calib  \
# 0                                        NotDetected
# 1                                        NotDetected
# 2                                               MSMS
# 3                                                MBR
# 4                                        NotDetected
#
#    Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C6-calib  \
# 0                                        NotDetected
# 1                                                MBR
# 2                                                MBR
# 3                                                MBR
# 4                                        NotDetected
#
#    Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C8-calib  \
# 0                                                MBR
# 1                                        NotDetected
# 2                                        NotDetected
# 3                                                MBR
# 4                                        NotDetected
#
#    Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C9-calib  Unnamed: 39
# 0                                                MBR                       NaN
# 1                                                MBR                       NaN
# 2                                        NotDetected                       NaN
# 3                                                MBR                       NaN
# 4                                        NotDetected                       NaN
#
# [5 rows x 40 columns]

# %%
# we need to get the PGM1 protein and see if it's kind of looking the same.

# %%
df_peptide_notshared = df[~df['Protein Groups'].str.contains(';')]
df_peptide_notshared 

df_peptide_shared = df[df['Protein Groups'].str.contains(';')]
df_peptide_shared

df_peptide_shared['gene_split'] = df_peptide_shared['Gene Names'].str.split(';')
# df_peptide_shared[['Gene Names', 'gene_split']]

#expand the rows. the concat onto other df
df2_pep_shared = df_peptide_shared.explode('gene_split').reset_index(drop=True)
df2_pep_shared['Gene Names'] = df2_pep_shared['Gene Names'].str.split(';').str[0]
df2_pep_shared = df2_pep_shared[df2_pep_shared['gene_split'] != ""] #without this line protein that have the format AAX; are added twice

df_combined = pd.concat([df_peptide_notshared, df2_pep_shared])
df_combined
# Out:
# /var/folders/zk/jc657sbs27l7_q82ygdlvxxc0000gp/T/ipykernel_39119/226859099.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_peptide_shared['gene_split'] = df_peptide_shared['Gene Names'].str.split(';')
#                 Sequence        Base Sequence    Protein Groups Gene Names  \
# 0            AAAAAAALQAK          AAAAAAALQAK            P36578       RPL4
# 1          AADAEAEVASLNR        AADAEAEVASLNR            P06753       TPM3
# 2              AAEDYGVIK            AAEDYGVIK         UNDEFINED        NaN
# 3    AAFDDAIAELDTLSEESYK  AAFDDAIAELDTLSEESYK            P62258      YWHAE
# 4              AAFGGSGGR            AAFGGSGGR         UNDEFINED        NaN
# ..                   ...                  ...               ...        ...
# 632            YLDGLTAER            YLDGLTAER  P35908;UNDEFINED       KRT2
# 634       YQELQVSAQLHGDR       YQELQVSAQLHGDR  Q8N1N4;UNDEFINED      KRT78
# 636          YSLEPVAVELK          YSLEPVAVELK  P00558;UNDEFINED       PGK1
# 638         YSVILLDTLLGR         YSVILLDTLLGR  P07988;UNDEFINED      SFTPB
# 640       YVDSEGHLYTVPIR       YVDSEGHLYTVPIR  Q03135;UNDEFINED       CAV1
#
#           Organism  \
# 0     Homo sapiens
# 1     Homo sapiens
# 2              NaN
# 3     Homo sapiens
# 4              NaN
# ..             ...
# 632  Homo sapiens;
# 634  Homo sapiens;
# 636  Homo sapiens;
# 638  Homo sapiens;
# 640  Homo sapiens;
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A1-calib  \
# 0                                             0.000000
# 1                                             0.000000
# 2                                             0.000000
# 3                                         16617.815755
# 4                                             0.000000
# ..                                                 ...
# 632                                         689.344778
# 634                                           0.000000
# 636                                        6589.581299
# 638                                           0.000000
# 640                                        9459.247965
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A2-calib  \
# 0                                           847.497855
# 1                                             0.000000
# 2                                         71568.381919
# 3                                          3419.939858
# 4                                             0.000000
# ..                                                 ...
# 632                                           0.000000
# 634                                           0.000000
# 636                                         654.253387
# 638                                           0.000000
# 640                                        7306.314442
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A3-calib  \
# 0                                           757.421795
# 1                                             0.000000
# 2                                             0.000000
# 3                                          5049.622344
# 4                                         24510.043524
# ..                                                 ...
# 632                                           0.000000
# 634                                        9015.579598
# 636                                        5414.498066
# 638                                           0.000000
# 640                                         544.002360
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A4-calib  \
# 0                                           894.366601
# 1                                          3633.850551
# 2                                             0.000000
# 3                                          7665.270626
# 4                                           508.788045
# ..                                                 ...
# 632                                       17079.837535
# 634                                           0.000000
# 636                                        2621.432530
# 638                                           0.000000
# 640                                       11707.278867
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A5-calib  ...  \
# 0                                           972.246076              ...
# 1                                             0.000000              ...
# 2                                             0.000000              ...
# 3                                          3659.233262              ...
# 4                                             0.000000              ...
# ..                                                 ...              ...
# 632                                        7488.906745              ...
# 634                                           0.000000              ...
# 636                                        6562.432293              ...
# 638                                           0.000000              ...
# 640                                         674.401735              ...
#
#      Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A10-calib  \
# 0                                                  MBR
# 1                                                  MBR
# 2                                          NotDetected
# 3                                                  MBR
# 4                                          NotDetected
# ..                                                 ...
# 632                                        NotDetected
# 634                                        NotDetected
# 636                                               MSMS
# 638                                        NotDetected
# 640                                        NotDetected
#
#      Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A11-calib  \
# 0                                          NotDetected
# 1                                          NotDetected
# 2                                          NotDetected
# 3                                                  MBR
# 4                                          NotDetected
# ..                                                 ...
# 632                                        NotDetected
# 634                                        NotDetected
# 636                                               MSMS
# 638                                               MSMS
# 640                                        NotDetected
#
#      Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C3-calib  \
# 0                                          NotDetected
# 1                                          NotDetected
# 2                                          NotDetected
# 3                                                  MBR
# 4                                          NotDetected
# ..                                                 ...
# 632                                        NotDetected
# 634                                        NotDetected
# 636                                        NotDetected
# 638                                               MSMS
# 640                                        NotDetected
#
#      Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C4-calib  \
# 0                                          NotDetected
# 1                                          NotDetected
# 2                                          NotDetected
# 3                                          NotDetected
# 4                                          NotDetected
# ..                                                 ...
# 632                                        NotDetected
# 634                                        NotDetected
# 636                                        NotDetected
# 638                                               MSMS
# 640                                        NotDetected
#
#      Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C5-calib  \
# 0                                          NotDetected
# 1                                          NotDetected
# 2                                                 MSMS
# 3                                                  MBR
# 4                                          NotDetected
# ..                                                 ...
# 632                                        NotDetected
# 634                                        NotDetected
# 636                                                MBR
# 638                                        NotDetected
# 640                                                MBR
#
#      Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C6-calib  \
# 0                                          NotDetected
# 1                                                  MBR
# 2                                                  MBR
# 3                                                  MBR
# 4                                          NotDetected
# ..                                                 ...
# 632                                        NotDetected
# 634                                        NotDetected
# 636                                        NotDetected
# 638                                        NotDetected
# 640                                        NotDetected
#
#      Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C8-calib  \
# 0                                                  MBR
# 1                                          NotDetected
# 2                                          NotDetected
# 3                                                  MBR
# 4                                          NotDetected
# ..                                                 ...
# 632                                        NotDetected
# 634                                        NotDetected
# 636                                        NotDetected
# 638                                               MSMS
# 640                                        NotDetected
#
#      Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C9-calib  \
# 0                                                  MBR
# 1                                                  MBR
# 2                                          NotDetected
# 3                                                  MBR
# 4                                          NotDetected
# ..                                                 ...
# 632                                                MBR
# 634                                        NotDetected
# 636                                        NotDetected
# 638                                        NotDetected
# 640                                                MBR
#
#      Unnamed: 39  gene_split
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ..           ...         ...
# 632          NaN        KRT2
# 634          NaN       KRT78
# 636          NaN        PGK1
# 638          NaN       SFTPB
# 640          NaN        CAV1
#
# [1415 rows x 41 columns]

# %%
df_combined.columns
# Out:
# Index(['Sequence', 'Base Sequence', 'Protein Groups', 'Gene Names', 'Organism',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A1-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A2-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A3-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A4-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A5-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A6-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A7-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A8-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_B02-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A10-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A11-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Resting_Chip1_C3-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Resting_Chip1_C4-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Resting_Chip1_C5-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Resting_Chip1_C6-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Resting_Chip1_C8-calib',
#        'Intensity_NanoPOTS_D022_Primary_SC_Resting_Chip1_C9-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A1-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A2-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A3-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A4-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A5-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A6-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A7-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A8-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_B02-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A10-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A11-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C3-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C4-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C5-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C6-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C8-calib',
#        'Detection Type_NanoPOTS_D022_Primary_SC_Resting_Chip1_C9-calib',
#        'Unnamed: 39', 'gene_split'],
#       dtype='object')

# %%
#how many proteins are there total?
df_combined = df_combined[['Gene Names','Sequence',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A1-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A2-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A3-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A4-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A5-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A6-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A7-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A8-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_B02-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A10-calib',
       'Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A11-calib',

   ]]

# %%
#Calculates the total spectral count for each row. Will help to find examples
def calc_totals(row):
    total = 0
    if row[2] != 0:
        total += 1
    if row[3] != 0:
        total += 1
    if row[4] != 0:
        total += 1
    if row[5] != 0:
        total += 1
    if row[6] != 0:
        total += 1
    if row[7] != 0:
        total += 1
    if row[8] != 0:
        total += 1
    if row[9] != 0:
        total += 1
    if row[10] != 0:
        total += 1
    if row[11] != 0:
        total += 1
    if row[12] != 0:
        total += 1
    

    return total


df_with_totals = df_combined.copy()
df_with_totals['Total_Count'] = df_with_totals.apply(calc_totals, axis = 1)
df_with_totals = df_with_totals[~df_with_totals['Gene Names'].isnull()]

# %%
df_with_totals
# Out:
#     Gene Names             Sequence  \
# 0         RPL4          AAAAAAALQAK
# 1         TPM3        AADAEAEVASLNR
# 3        YWHAE  AAFDDAIAELDTLSEESYK
# 7         ENO1   AAVPSGASTGIYEALELR
# 10        TLN1        ADAEGESDLENSR
# ..         ...                  ...
# 632       KRT2            YLDGLTAER
# 634      KRT78       YQELQVSAQLHGDR
# 636       PGK1          YSLEPVAVELK
# 638      SFTPB         YSVILLDTLLGR
# 640       CAV1       YVDSEGHLYTVPIR
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A1-calib  \
# 0                                             0.000000
# 1                                             0.000000
# 3                                         16617.815755
# 7                                          1119.113732
# 10                                            0.000000
# ..                                                 ...
# 632                                         689.344778
# 634                                           0.000000
# 636                                        6589.581299
# 638                                           0.000000
# 640                                        9459.247965
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A2-calib  \
# 0                                           847.497855
# 1                                             0.000000
# 3                                          3419.939858
# 7                                             0.000000
# 10                                         3052.379968
# ..                                                 ...
# 632                                           0.000000
# 634                                           0.000000
# 636                                         654.253387
# 638                                           0.000000
# 640                                        7306.314442
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A3-calib  \
# 0                                           757.421795
# 1                                             0.000000
# 3                                          5049.622344
# 7                                         11066.863565
# 10                                            0.000000
# ..                                                 ...
# 632                                           0.000000
# 634                                        9015.579598
# 636                                        5414.498066
# 638                                           0.000000
# 640                                         544.002360
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A4-calib  \
# 0                                           894.366601
# 1                                          3633.850551
# 3                                          7665.270626
# 7                                          1039.477670
# 10                                          463.707933
# ..                                                 ...
# 632                                       17079.837535
# 634                                           0.000000
# 636                                        2621.432530
# 638                                           0.000000
# 640                                       11707.278867
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A5-calib  \
# 0                                           972.246076
# 1                                             0.000000
# 3                                          3659.233262
# 7                                          3933.443849
# 10                                            0.000000
# ..                                                 ...
# 632                                        7488.906745
# 634                                           0.000000
# 636                                        6562.432293
# 638                                           0.000000
# 640                                         674.401735
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A6-calib  \
# 0                                           813.713706
# 1                                             0.000000
# 3                                          5585.499010
# 7                                             0.000000
# 10                                            0.000000
# ..                                                 ...
# 632                                           0.000000
# 634                                           0.000000
# 636                                           0.000000
# 638                                           0.000000
# 640                                           0.000000
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A7-calib  \
# 0                                          1158.033005
# 1                                           687.944252
# 3                                          2193.579785
# 7                                             0.000000
# 10                                            0.000000
# ..                                                 ...
# 632                                           0.000000
# 634                                           0.000000
# 636                                           0.000000
# 638                                           0.000000
# 640                                           0.000000
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A8-calib  \
# 0                                         3.393189e+03
# 1                                         5.255998e+03
# 3                                         8.545698e+03
# 7                                         5.927423e+03
# 10                                        0.000000e+00
# ..                                                 ...
# 632                                       5.010308e+02
# 634                                       0.000000e+00
# 636                                       6.382788e+03
# 638                                       1.054437e+06
# 640                                       2.033016e+02
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_B02-calib  \
# 0                                             0.000000
# 1                                             0.000000
# 3                                          2830.669209
# 7                                          4703.395748
# 10                                            0.000000
# ..                                                 ...
# 632                                           0.000000
# 634                                           0.000000
# 636                                           0.000000
# 638                                        2162.207171
# 640                                           0.000000
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A10-calib  \
# 0                                          1724.883637
# 1                                          2920.678138
# 3                                          6035.617534
# 7                                          6730.957909
# 10                                            0.000000
# ..                                                 ...
# 632                                           0.000000
# 634                                           0.000000
# 636                                       16357.668836
# 638                                           0.000000
# 640                                           0.000000
#
#      Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A11-calib  \
# 0                                         0.000000e+00
# 1                                         0.000000e+00
# 3                                         4.698057e+03
# 7                                         0.000000e+00
# 10                                        0.000000e+00
# ..                                                 ...
# 632                                       0.000000e+00
# 634                                       0.000000e+00
# 636                                       7.528058e+03
# 638                                       1.166472e+06
# 640                                       0.000000e+00
#
#      Total_Count
# 0              8
# 1              4
# 3             11
# 7              7
# 10             2
# ..           ...
# 632            4
# 634            1
# 636            8
# 638            3
# 640            6
#
# [814 rows x 14 columns]

# %%
df_gene_ind = df_with_totals.set_index(['Gene Names', 'Sequence']) #create a multiindex dataframe
df_gene_ind = df_gene_ind[df_gene_ind['Total_Count']>0]#drop rows that don't have any intensities in any col. Who knows why that's a thing
df_gene_ind.sort_index()
# Out:
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A1-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                           0.000000
#              SVTEQGAELSNEER                                                                               0.000000
#              TAFDEAIAELDTLSEESYK                                                                      10135.560384
#              YLAEVAAGDDK                                                                               3108.313507
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                              0.000000
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A2-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                       25083.428947
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                        4042.138087
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                        7245.155977
#              QEYDEAGPSIVHR                                                                            27483.926661
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                           0.000000
#              SVTEQGAELSNEER                                                                               0.000000
#              TAFDEAIAELDTLSEESYK                                                                       6311.119170
#              YLAEVAAGDDK                                                                                  0.000000
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                           2276.544798
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A3-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                             3585.651341
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                         707.699281
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                        2323.757868
#              SVTEQGAELSNEER                                                                               0.000000
#              TAFDEAIAELDTLSEESYK                                                                          0.000000
#              YLAEVAAGDDK                                                                               1389.841342
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                           1038.292234
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A4-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                        1592.733347
#              SVTEQGAELSNEER                                                                            1094.235054
#              TAFDEAIAELDTLSEESYK                                                                       1734.073679
#              YLAEVAAGDDK                                                                               1750.237640
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                           7125.716941
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A5-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                        7973.130007
#              SVTEQGAELSNEER                                                                            5475.911203
#              TAFDEAIAELDTLSEESYK                                                                          0.000000
#              YLAEVAAGDDK                                                                               5835.616365
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                           4343.478414
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A6-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                           0.000000
#              SVTEQGAELSNEER                                                                               0.000000
#              TAFDEAIAELDTLSEESYK                                                                          0.000000
#              YLAEVAAGDDK                                                                                  0.000000
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                           2147.410463
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A7-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                           0.000000
#              SVTEQGAELSNEER                                                                               0.000000
#              TAFDEAIAELDTLSEESYK                                                                          0.000000
#              YLAEVAAGDDK                                                                                  0.000000
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                           4687.752889
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A8-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                         484.324292
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                        3966.257065
#              SVTEQGAELSNEER                                                                               0.000000
#              TAFDEAIAELDTLSEESYK                                                                       6738.273413
#              YLAEVAAGDDK                                                                               3646.261468
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                           1550.189245
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_B02-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                        3277.603777
#              SVTEQGAELSNEER                                                                               0.000000
#              TAFDEAIAELDTLSEESYK                                                                      17095.740940
#              YLAEVAAGDDK                                                                               5835.834225
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                              0.000000
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A10-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                        6118.466763
#              SVTEQGAELSNEER                                                                               0.000000
#              TAFDEAIAELDTLSEESYK                                                                          0.000000
#              YLAEVAAGDDK                                                                               8414.152221
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                           2087.803914
#
#                                                                  Intensity_NanoPOTS_D022_Primary_SC_Non_Resting_Chip1_A11-calib  \
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                                                0.000000
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...                                           0.000000
#              QEYDEAGPSIVHR                                                                                0.000000
# ...                                                                                                            ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                                                           0.000000
#              SVTEQGAELSNEER                                                                               0.000000
#              TAFDEAIAELDTLSEESYK                                                                       2825.392987
#              YLAEVAAGDDK                                                                                  0.000000
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                                                              0.000000
#
#                                                                  Total_Count
# Gene Names   Sequence
# A2ML1        VSGVGNNISFEEK                                                 1
# ACTA2|ACTC1  DLYANNVLSGGTTM[Common Variable:Oxidation on M]Y...            1
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...            2
#              LC[Common Fixed:Carbamidomethyl on C]YVALDFENEM...            2
#              QEYDEAGPSIVHR                                                 1
# ...                                                                      ...
# YWHAZ        GIVDQSQQAYQEAFEISK                                            6
#              SVTEQGAELSNEER                                                2
#              TAFDEAIAELDTLSEESYK                                           6
#              YLAEVAAGDDK                                                   7
# |RAP1B|RAP1A SALTVQFVQGIFVEK                                               8
#
# [795 rows x 12 columns]

# %%
len(list(df_gene_ind.index.get_level_values('Gene Names').unique()))
# Out:
# 237

# %%
len(list(df_gene_ind.index.get_level_values('Sequence')))
# Out:
# 795

# %%
no_consistent= []
one_consistent = []
two_consistent = []
three_consistent = []
fourplus_consistent = []

num_proteins = 0

for gene, gene_df in df_gene_ind.groupby(level=0):
    num_proteins+=1
    #loop through each gene and count the number of consistent peptides
    if len(gene_df[gene_df['Total_Count'] == 11]) == 0:
        no_consistent.append(gene)
    elif len(gene_df[gene_df['Total_Count'] == 11]) == 1:
        one_consistent.append(gene)
    elif len(gene_df[gene_df['Total_Count'] == 11]) == 2:
#         import pdb; pdb.set_trace()
        two_consistent.append(gene)
    elif len(gene_df[gene_df['Total_Count'] == 11]) == 3:
        three_consistent.append(gene)
    elif len(gene_df[gene_df['Total_Count'] == 11]) >= 4:
        fourplus_consistent.append(gene)
        
    else:
        print('something is wrong')

# %%
len(fourplus_consistent)
# Out:
# 0

# %%
len(three_consistent)
# Out:
# 2

# %%
num_proteins
# Out:
# 237

# %%
'''
returns a dictionary where the key is the number of peptides, 
and the value is the number of proteins
Example: 5:4 would mean that 4 proteins consist of 5 peptides
'''
def get_num_pep_dict(df_with_totals, pep_consistency_list):
    subdf = df_with_totals[df_with_totals['Gene Names'].isin(pep_consistency_list)]
    subdf = subdf.set_index(['Gene Names', 'Sequence']) #create a multiindex dataframe
    subdf = subdf[subdf['Total_Count']>0]#drop rows that don't have any intensities in any col. Who knows why that's a thing
    subdf = subdf.sort_index()
    
    
    num_pep_consis = {}
    for gene, gene_df in subdf.groupby(level=0):
        num_peptides = len(gene_df)
        if num_peptides not in num_pep_consis.keys():    
            num_pep_consis[num_peptides] = 1
        else:
            num_pep_consis[num_peptides] += 1

    return num_pep_consis

# %%
no_consis_d = get_num_pep_dict(df_with_totals, no_consistent)
one_consis_d = get_num_pep_dict(df_with_totals, one_consistent)
two_consis_d = get_num_pep_dict(df_with_totals, two_consistent)
three_consis_d = get_num_pep_dict(df_with_totals, three_consistent)
fourplus_consis_d = get_num_pep_dict(df_with_totals, fourplus_consistent)

# %%
no_consis_d
# Out:
# {1: 103,
#  5: 10,
#  3: 23,
#  11: 2,
#  2: 41,
#  4: 9,
#  6: 9,
#  9: 3,
#  15: 1,
#  28: 1,
#  8: 3,
#  31: 1,
#  14: 1}

# %% [markdown]
# ## make figure

# %%
num_pep_0consis_series = pd.Series(no_consis_d)
num_pep_1consis_series = pd.Series(one_consis_d)
num_pep_2consis_series = pd.Series(two_consis_d)
num_pep_3consis_series = pd.Series(three_consis_d)
num_pep_4plusconsis_series = pd.Series(fourplus_consis_d)
# Out:
# /var/folders/zk/jc657sbs27l7_q82ygdlvxxc0000gp/T/ipykernel_39119/3207798562.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   num_pep_4plusconsis_series = pd.Series(fourplus_consis_d)

# %%
plotdf = pd.concat([num_pep_0consis_series,
           num_pep_1consis_series,
          num_pep_2consis_series,
          num_pep_3consis_series,
          num_pep_4plusconsis_series],axis=1)

plotdf.rename({0:'0 consistent peptide',
              1:'1 consistent peptide',
              2:'2 consistent peptide',
              3:'3 consistent peptide',
              4:'4+ consistent peptide'}, axis=1, inplace=True)

plotdf = plotdf.sort_index()

# %%
plotdf #index is the number of peptides in a protein. Values are the number of proteins
# Out:
#     0 consistent peptide  1 consistent peptide  2 consistent peptide  \
# 1                  103.0                   6.0                   NaN
# 2                   41.0                   8.0                   NaN
# 3                   23.0                   2.0                   1.0
# 4                    9.0                   3.0                   1.0
# 5                   10.0                   NaN                   NaN
# 6                    9.0                   NaN                   NaN
# 8                    3.0                   NaN                   1.0
# 9                    3.0                   NaN                   NaN
# 11                   2.0                   NaN                   NaN
# 13                   NaN                   1.0                   1.0
# 14                   1.0                   NaN                   NaN
# 15                   1.0                   NaN                   NaN
# 16                   NaN                   NaN                   NaN
# 18                   NaN                   NaN                   1.0
# 21                   NaN                   NaN                   1.0
# 22                   NaN                   1.0                   NaN
# 28                   1.0                   NaN                   NaN
# 31                   1.0                   NaN                   NaN
# 40                   NaN                   1.0                   NaN
# 42                   NaN                   NaN                   NaN
#
#     3 consistent peptide  4+ consistent peptide
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                    NaN                    NaN
# 5                    NaN                    NaN
# 6                    NaN                    NaN
# 8                    NaN                    NaN
# 9                    NaN                    NaN
# 11                   NaN                    NaN
# 13                   NaN                    NaN
# 14                   NaN                    NaN
# 15                   NaN                    NaN
# 16                   1.0                    NaN
# 18                   NaN                    NaN
# 21                   NaN                    NaN
# 22                   NaN                    NaN
# 28                   NaN                    NaN
# 31                   NaN                    NaN
# 40                   NaN                    NaN
# 42                   1.0                    NaN

# %%
plotdf.sum()
# Out:
# 0 consistent peptide     207.0
# 1 consistent peptide      22.0
# 2 consistent peptide       6.0
# 3 consistent peptide       2.0
# 4+ consistent peptide      0.0
# dtype: float64

# %%
num_prot = len(list(df_gene_ind.index.get_level_values('Gene Names').unique()))

# %%
num_prot
# Out:
# 237

# %%
print('0 consistent: ' + str(round(229/num_prot*100, 2)))
print('1 consistent: ' + str(round(241/num_prot*100, 2)))
print('2 consistent: ' + str(round(79/num_prot*100,2)))
print('3 consistent: ' + str(round(31/num_prot*100,2)))
print('4+ consistent: ' + str(round(45/num_prot*100,2)))
# Out:
# 0 consistent: 96.62
# 1 consistent: 101.69
# 2 consistent: 33.33
# 3 consistent: 13.08
# 4+ consistent: 18.99

# %%
268+103+65+138
# Out:
# 574
